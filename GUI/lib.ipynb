# %%
pip install transformers plotly
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ----------- ---------------------------- 3.4/12.0 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.0 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 25.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    --------------------------------------- 566.1/566.1 kB 19.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 30.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpuNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#      -------------------------------------- 536.2/536.2 kB 4.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    ---------------------------------------- 1.0/110.9 MB 4.6 MB/s eta 0:00:25
#    - -------------------------------------- 2.9/110.9 MB 6.7 MB/s eta 0:00:17
#    - -------------------------------------- 3.9/110.9 MB 7.1 MB/s eta 0:00:16
#    - -------------------------------------- 3.9/110.9 MB 7.1 MB/s eta 0:00:16
#    - -------------------------------------- 3.9/110.9 MB 7.1 MB/s eta 0:00:16
#    --- ------------------------------------ 9.2/110.9 MB 7.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 12.3/110.9 MB 8.6 MB/s eta 0:00:12
# ...

# %%
pip install streamlit opencv-python torch torchvision transformers timm plotly pillow joblib scikit-learn numpy
# Out:
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------------------- ------------ 4.2/6.2 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 22.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 29.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
# ...
# Note: you may need to restart the kernel to use updated packages.
